# %% [markdown]
# <a href="https://colab.research.google.com/github/MehdiH7/Text-to-Image/blob/main/Text_to_Image_using_stable_diffusion_v1_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# !pip install diffusers
import torch
import numpy as np
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import torch
import numpy as np
from diffusers import StableDiffusionPipeline, EulerDiscreteScheduler
from PIL import Image
# !pip install accelerate

# set up the model
model_id = "runwayml/stable-diffusion-v1-5"
device = "cuda"
pipe = StableDiffusionPipeline.from_pretrained(model_id, torch_dtype=torch.float16)
pipe = pipe.to("cuda")

# set up the prompt
prompt = "banner iphone 14 for a webpage"

# generate the image
image = pipe(prompt).images[0] 
image = np.array(image)
image = Image.fromarray(image)

# save the image
image.save("astronaut_rides_horse4.png")
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   0%|          | 0/50 [00:00<?, ?it/s]
